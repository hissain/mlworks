# %%
import pickle
with open("scraped_chunks.pkl", "rb") as f:
    data = pickle.load(f)
print(len(data))
# Out:
# 299

# %%
import requests
import json
import pandas as pd
import re

ollama_url_gen = "http://localhost:11434/api/generate"
ollama_model_name = "llama3.2:latest"

def generate_qa_pairs(chunk, model=ollama_model_name):
    prompt = f"""
You are an expert assistant skilled at generating question-answer pairs for text comprehension. 
Given a text chunk, generate diverse, relevant, and accurate question-answer pairs that cover the key information in the chunk. 
Your output should be a list of pairs in JSON format, where each pair includes a "question" and its corresponding "answer."

Example:
Chunk: "The Eiffel Tower is a wrought-iron lattice tower located on the Champ de Mars in Paris, France. It was designed by Gustave Eiffel's engineering company and completed in 1889."

Output:
[
  {{"question": "Where is the Eiffel Tower located?", "answer": "The Eiffel Tower is located on the Champ de Mars in Paris, France."}},
  {{"question": "Who designed the Eiffel Tower?", "answer": "The Eiffel Tower was designed by Gustave Eiffel's engineering company."}},
  {{"question": "When was the Eiffel Tower completed?", "answer": "The Eiffel Tower was completed in 1889."}}
]

Now, process the following chunk:
Chunk: {chunk}
"""
    
    payload = {"model": model, "prompt": prompt, "stream": False}
    headers = {"Content-Type": "application/json"}
    response = requests.post(ollama_url_gen, headers=headers, data=json.dumps(payload))
    
    if response.status_code != 200:
        raise Exception(f"Error from Ollama: {response.text}")
    
    content = response.json().get("response", "")
    try:
        json_match = re.search(r"\[.*?\]", content, re.DOTALL)
        if json_match:
            raw_json = json_match.group()
            sanitized_json = re.sub(r",\s*]", "]", raw_json)
            qa_pairs = json.loads(sanitized_json)
            return qa_pairs
        else:
            raise Exception(f"Valid JSON not found in response: {content}")
    except json.JSONDecodeError as e:
        raise Exception(f"Failed to parse JSON response: {content}")

# %%
df_chunks = pd.DataFrame(data)[1:3]

# %%
df_chunks
# Out:
#                                                    0  \
# 1  List | War | Death range | Date | Combatants |...
# 2  List | War | Death range | Date | Combatants |...
#
#                                                    1
# 1  https://en.wikipedia.org/wiki/List_of_wars_by_...
# 2  https://en.wikipedia.org/wiki/List_of_wars_by_...

# %%
from tqdm.notebook import tqdm

qa_data = []
for _, row in tqdm(df_chunks.iterrows(), total=len(df_chunks)):
    chunk_id = row[1]
    chunk_text = row[0]
    try:
        qa_pairs = generate_qa_pairs(chunk_text)
        for pair in qa_pairs:
            qa_data.append({
                "chunk_id": chunk_id,
                "question": pair["question"],
                "answer": pair["answer"]
            })
    except Exception as e:
        print(f"Error processing chunk {chunk_id}: {e}")

df_qa = pd.DataFrame(qa_data)
df_qa.to_csv("qa_pairs.csv", index=False)
print("QA pairs saved to qa_pairs.csv")
# Out:
#   0%|          | 0/2 [00:00<?, ?it/s]
# QA pairs saved to qa_pairs.csv

# %%
df_qa
# Out:
#                                              chunk_id  \
# 0   https://en.wikipedia.org/wiki/List_of_wars_by_...
# 1   https://en.wikipedia.org/wiki/List_of_wars_by_...
# 2   https://en.wikipedia.org/wiki/List_of_wars_by_...
# 3   https://en.wikipedia.org/wiki/List_of_wars_by_...
# 4   https://en.wikipedia.org/wiki/List_of_wars_by_...
# 5   https://en.wikipedia.org/wiki/List_of_wars_by_...
# 6   https://en.wikipedia.org/wiki/List_of_wars_by_...
# 7   https://en.wikipedia.org/wiki/List_of_wars_by_...
# 8   https://en.wikipedia.org/wiki/List_of_wars_by_...
# 9   https://en.wikipedia.org/wiki/List_of_wars_by_...
# 10  https://en.wikipedia.org/wiki/List_of_wars_by_...
# 11  https://en.wikipedia.org/wiki/List_of_wars_by_...
# 12  https://en.wikipedia.org/wiki/List_of_wars_by_...
# 13  https://en.wikipedia.org/wiki/List_of_wars_by_...
# 14  https://en.wikipedia.org/wiki/List_of_wars_by_...
# 15  https://en.wikipedia.org/wiki/List_of_wars_by_...
# 16  https://en.wikipedia.org/wiki/List_of_wars_by_...
# 17  https://en.wikipedia.org/wiki/List_of_wars_by_...
# 18  https://en.wikipedia.org/wiki/List_of_wars_by_...
# 19  https://en.wikipedia.org/wiki/List_of_wars_by_...
# 20  https://en.wikipedia.org/wiki/List_of_wars_by_...
# 21  https://en.wikipedia.org/wiki/List_of_wars_by_...
# 22  https://en.wikipedia.org/wiki/List_of_wars_by_...
# 23  https://en.wikipedia.org/wiki/List_of_wars_by_...
# 24  https://en.wikipedia.org/wiki/List_of_wars_by_...
# 25  https://en.wikipedia.org/wiki/List_of_wars_by_...
# 26  https://en.wikipedia.org/wiki/List_of_wars_by_...
# 27  https://en.wikipedia.org/wiki/List_of_wars_by_...
# 28  https://en.wikipedia.org/wiki/List_of_wars_by_...
# 29  https://en.wikipedia.org/wiki/List_of_wars_by_...
# 30  https://en.wikipedia.org/wiki/List_of_wars_by_...
# 31  https://en.wikipedia.org/wiki/List_of_wars_by_...
# 32  https://en.wikipedia.org/wiki/List_of_wars_by_...
# 33  https://en.wikipedia.org/wiki/List_of_wars_by_...
# 34  https://en.wikipedia.org/wiki/List_of_wars_by_...
# 35  https://en.wikipedia.org/wiki/List_of_wars_by_...
# 36  https://en.wikipedia.org/wiki/List_of_wars_by_...
# 37  https://en.wikipedia.org/wiki/List_of_wars_by_...
# 38  https://en.wikipedia.org/wiki/List_of_wars_by_...
# 39  https://en.wikipedia.org/wiki/List_of_wars_by_...
# 40  https://en.wikipedia.org/wiki/List_of_wars_by_...
# 41  https://en.wikipedia.org/wiki/List_of_wars_by_...
# 42  https://en.wikipedia.org/wiki/List_of_wars_by_...
# 43  https://en.wikipedia.org/wiki/List_of_wars_by_...
# 44  https://en.wikipedia.org/wiki/List_of_wars_by_...
# 45  https://en.wikipedia.org/wiki/List_of_wars_by_...
# 46  https://en.wikipedia.org/wiki/List_of_wars_by_...
# 47  https://en.wikipedia.org/wiki/List_of_wars_by_...
# 48  https://en.wikipedia.org/wiki/List_of_wars_by_...
# 49  https://en.wikipedia.org/wiki/List_of_wars_by_...
# 50  https://en.wikipedia.org/wiki/List_of_wars_by_...
# 51  https://en.wikipedia.org/wiki/List_of_wars_by_...
# 52  https://en.wikipedia.org/wiki/List_of_wars_by_...
#
#                                              question  \
# 0   What was the approximate number of deaths caus...
# 1   What were the combatants involved in World War...
# 2                   When did World War II take place?
# 3        Which location was affected by World War II?
# 4   What were the approximate number of deaths cau...
# 5   Who did the Mongols invade and conquer during ...
# 6   Where did the Mongol invasions and conquests t...
# 7   What was the approximate number of deaths caus...
# 8   Which dates mark the beginning and end of the ...
# 9   Who were the various sides involved in the Thr...
# 10           Where did the Three Kingdoms take place?
# 11  What was the approximate number of deaths caus...
# 12  Which dynasties were involved in the Taiping R...
# 13        Where did the Taiping Rebellion take place?
# 14  What was the approximate number of deaths caus...
# 15         Which powers were involved in World War I?
# 16                  Where did World War I take place?
# 17  What was the approximate number of deaths caus...
# 18  Which dynasties were involved in the Manchu Co...
# 19  Where did the Manchu Conquest of China take pl...
# 20  What was the approximate number of deaths caus...
# 21  Which empires were involved in the Conquests o...
# 22       Where did the Conquests of Timur take place?
# 23  What was the approximate number of deaths caus...
# 24  Which dynasties were involved in the An Lushan...
# 25      Where did the An Lushan rebellion take place?
# 26  What was the approximate number of deaths caus...
# 27  Which sides were involved in the Thirty Years'...
# 28        Where did the Thirty Years' War take place?
# 29  What was the approximate number of deaths caus...
# 30  Which empires were involved in the Spanish con...
# 31  Where did the Spanish conquest of Mexico take ...
# 32  What was the approximate number of deaths caus...
# 33  Which empires were involved in the Spanish con...
# 34  Where did the Spanish conquest of the Inca Emp...
# 35  What was the approximate number of deaths caus...
# 36  Which sides were involved in the Russian Civil...
# 37        Where did the Russian Civil War take place?
# 38  What was the approximate number of deaths caus...
# 39  Which sides were involved in the Chinese Civil...
# 40        Where did the Chinese Civil War take place?
# 41  What conflict resulted in the deaths of betwee...
# 42  What was the approximate number of deaths duri...
# 43  When did the French Revolutionary and Napoleon...
# 44  Who were the main combatants in the Second Con...
# 45  What was the approximate number of deaths duri...
# 46  What conflict took place in the Indian subcont...
# 47  What was the estimated number of deaths during...
# 48                    When did the Deluge take place?
# 49  Who were the main combatants in the French War...
# 50  What conflict took place in the Korean Peninsu...
# 51               When did the Vietnam War take place?
# 52  Who were the main combatants in the Second Con...
#
#                                                answer
# 0                                       50-85 million
# 1                       Allied Powers vs. Axis Powers
# 2                                           1939–1945
# 3                                              Global
# 4                                       20-60 million
# 5         Mongol Empire vs. various states in Eurasia
# 6                                     Asia and Europe
# 7                                          34 million
# 8                                             220–280
# 9                                      Multiple sides
# 10                                              China
# 11                                      20-30 million
# 12          Qing Dynasty vs. Taiping Heavenly Kingdom
# 13                                              China
# 14                                      15-30 million
# 15                   Allied Powers vs. Central Powers
# 16                                             Global
# 17                                         25 million
# 18                            Manchu vs. Ming Dynasty
# 19                                              China
# 20                                       7-20 million
# 21          Timurid Empire vs. various states in Asia
# 22            Central Asia, West Asia, and South Asia
# 23                                         13 million
# 24  Tang Dynasty and Uyghur Khaganate vs. Yan Dynasty
# 25                                              China
# 26                                       4-12 million
# 27       Anti-Imperial Alliance vs. Imperial Alliance
# 28                                             Europe
# 29                                       10.5 million
# 30  Spanish Empire and allies vs. Aztec Empire and...
# 31                                             Mexico
# 32                                         10 million
# 33                     Spanish Empire vs. Inca Empire
# 34                                      South America
# 35                                       7-10 million
# 36  Multiple sides; Bolsheviks, Anti-Bolshevik lef...
# 37                                             Russia
# 38                                        4-9 million
# 39  Multiple sides; but predominantly Communists v...
# 40                                              China
# 41                                       The Crusades
# 42                                          7 million
# 43                                          1792–1815
# 44                                     Multiple sides
# 45                                       5.25 million
# 46                                    The Deccan wars
# 47                                   3.04–4.1 million
# 48                                          1648–1666
# 49                      French Catholics vs Huguenots
# 50                                     The Korean War
# 51                                          1955–1975
# 52                                     Multiple sides

# %%
import requests
import json
import pandas as pd
import re
from tqdm.notebook import tqdm
import pickle

ollama_url_gen = "http://localhost:11434/api/generate"
ollama_model_name = "llama3.2:latest"


def generate_qa_pairs(chunk, model=ollama_model_name):
    prompt = f"""
You are an expert assistant skilled at generating question-answer pairs for text comprehension. 
Given a text chunk, generate diverse, relevant, and accurate question-answer pairs that cover the key information in the chunk. 
Your output should be a list of pairs in JSON format, where each pair includes a "question" and its corresponding "answer."

Example:
Chunk: "The Eiffel Tower is a wrought-iron lattice tower located on the Champ de Mars in Paris, France. It was designed by Gustave Eiffel's engineering company and completed in 1889."

Output:
[
  {{"question": "Where is the Eiffel Tower located?", "answer": "The Eiffel Tower is located on the Champ de Mars in Paris, France."}},
  {{"question": "Who designed the Eiffel Tower?", "answer": "The Eiffel Tower was designed by Gustave Eiffel's engineering company."}},
  {{"question": "When was the Eiffel Tower completed?", "answer": "The Eiffel Tower was completed in 1889."}}
]

Now, process the following chunk:
Chunk: {chunk}
"""
    payload = {"model": model, "prompt": prompt, "stream": False}
    headers = {"Content-Type": "application/json"}
    response = requests.post(ollama_url_gen, headers=headers, data=json.dumps(payload))
    
    if response.status_code != 200:
        raise Exception(f"Error from Ollama: {response.text}")
    
    content = response.json().get("response", "")
    try:
        json_match = re.search(r"\[.*?\]", content, re.DOTALL)
        if json_match:
            raw_json = json_match.group()
            sanitized_json = re.sub(r",\s*]", "]", raw_json)
            qa_pairs = json.loads(sanitized_json)
            return qa_pairs
        else:
            raise Exception(f"Valid JSON not found in response: {content}")
    except json.JSONDecodeError as e:
        raise Exception(f"Failed to parse JSON response: {content}")


with open("scraped_chunks.pkl", "rb") as f:
    data = pickle.load(f)[1:3]
    
df_chunks = pd.DataFrame(data, columns=["chunk_text", "url"])

rag_chunks = []
for _, row in tqdm(df_chunks.iterrows(), total=len(df_chunks)):
    chunk_text = row["chunk_text"]
    url = row["url"]
    try:
        qa_pairs = generate_qa_pairs(chunk_text)
        for pair in qa_pairs:
            new_chunk = {
                "text": f"Q: {pair['question']} A: {pair['answer']}",
                "url": url
            }
            rag_chunks.append(new_chunk)
    except Exception as e:
        print(f"Error processing chunk: {e}")

df_rag_chunks = pd.DataFrame(rag_chunks)
df_rag_chunks.to_pickle("rag_chunks.pkl")
df_rag_chunks.to_csv("rag_chunks.csv", index=False)

print("RAG chunks saved to 'rag_chunks.pkl' and 'rag_chunks.csv'")
# Out:
#   0%|          | 0/2 [00:00<?, ?it/s]
# Error processing chunk: Valid JSON not found in response: Here are the question-answer pairs for the given chunk in JSON format:
#
# [
#   {"question": "What was the estimated number of deaths in the crusades?", "answer": "1 – 9 million"},
#   {"question": "Where did the crusades take place?", "answer": "The crusades took place in Europe and the Middle East."},
#   {"question": "Who were the main combatants in the crusades?", "answer": "Originally byzantine empire vs. seljuk empire, but evolved into christians vs. muslims"},
#   {"question": "When did the crusades occur?", "answer": "The crusades occurred from 1095 – 1291"},
#   {"question": "What was the name of the conflict that followed the Reconquista?", "answer": "Reconquista"},
#   {"question": "How many people were killed in the Reconquista?", "answer": "7 million"},
#   {"question": "Where did the Reconquista take place?", "answer": "The Reconquista took place in the Iberian Peninsula"},
#   {"question": "Who were the main combatants in the Reconquista?", "answer": "Spanish and Portuguese Christians vs. Spanish and Portuguese Muslims"},
#   {"question": "When did the Reconquista occur?", "answer": "The Reconquista occurred from 718–1492"},
#   {"question": "What was the name of the conflict that took place during the French Revolutionary and Napoleonic Wars?", "answer": "French Revolutionary and Napoleonic Wars"},
#   {"question": "How many people were killed in the French Revolutionary and Napoleonic Wars?", "answer": "5–7 million"},
#   {"question": "When did the French Revolutionary and Napoleonic Wars occur?", "answer": "The French Revolutionary and Napoleonic Wars occurred from 1792–1815"},
#   {"question": "Who were the main combatants in the French Revolutionary and Napoleonic Wars?", "answer": "French Republic, later French Empire, vs. Coalition forces"},
#   {"question": "Where did the French Revolutionary and Napoleonic Wars take place?", "answer": "Europe"},
#   {"question": "What was the name of the conflict that took place in Ethiopia during Menelik II's reign?", "answer": "Conquests of Menelik II"},
#   {"question": "How many people were killed in the Conquests of Menelik II?", "answer": "6 million"},
#   {"question": "When did the Conquests of Menelik II occur?", "answer": "The Conquests of Menelik II occurred from 1878–1904"},
#   {"question": "Who were the main combatants in the Conquests of Menelik II?", "answer": "Ethiopian Empire vs. Emirate of Harar, Kingdom of Kaffa, Kingdom of Wolaita, and allies"},
#   {"question": "Where did the Conquests of Menelik II take place?", "answer": "The Conquests of Menelik II took place in the Horn of Africa"},
#   {"question": "What was the name of the conflict that took place in the Democratic Republic of the Congo from 1998–2003?", "answer": "Second Congo War"},
#   {"question": "How many people were killed in the Second Congo War?", "answer": "3–5.4 million"},
#   {"question": "When did the Second Congo War occur?", "answer": "The Second Congo War occurred from 1998–2003"},
#   {"question": "Who were the main combatants in the Second Congo War?", "answer": "Multiple sides"},
#   {"question": "Where did the Second Congo War take place?", "answer": "The Second Congo War took place in the Democratic Republic of the Congo"},
#   {"question": "What was the name of the conflict that took place in Colombia from 1525–1540?", "answer": "Spanish conquest of New Granada"},
#   {"question": "How many people were killed in the Spanish conquest of New Granada?", "answer": "5.25 million"},
#   {"question": "When did the Spanish conquest of New Granada occur?", "answer": "The Spanish conquest of New Granada occurred from 1525–1540"},
#   {"question": "Who were the main combatants in the Spanish conquest of New Granada?", "answer": "Spanish Empire and Klein-Venedig vs. Muisca Confederation and other civilizations"},
#   {"question": "Where did the Spanish conquest of New Granada take place?", "answer": "The Spanish conquest of New Granada took place in Colombia"},
#   {"question": "What was the name of the conflict that took place in India from 1680–1707?", "answer": "Deccan wars"},
#   {"question": "How many people were killed in the Deccan wars?", "answer": "4.6–5 million"},
#   {"question": "When did the Deccan wars occur?", "answer": "The Deccan wars occurred from 1680–1707"},
#   {"question": "Who were the main combatants in the Deccan wars?", "answer": "Mughal Empire vs. Maratha Confederacy"},
#   {"question": "Where did the Deccan wars take place?", "answer": "The Deccan wars took place in the Indian subcontinent"},
#   {"question": "What was the name of the conflict that took place in Nigeria from 1967–1970?", "answer": "Nigerian Civil War"},
#   {"question": "How many people were killed in the Nigerian Civil War?", "answer": "3.04–4.1 million"},
#   {"question": "When did the Nigerian Civil War occur?", "answer": "The Nigerian Civil War occurred from 1967–1970"},
#   {"question": "Who were the main combatants in the Nigerian Civil War?", "answer": "Nigeria vs. Biafra"},
#   {"question": "Where did the Nigerian Civil War take place?", "answer": "The Nigerian Civil War took place in Nigeria"},
#   {"question": "What was the name of the conflict that occurred in Poland–Lithuania from 1648–1666?", "answer": "Deluge"},
#   {"question": "How many people were killed in the Deluge?", "answer": "A variable amount, as the exact number is not provided"},
#   {"question": "When did the Deluge occur?", "answer": "The Deluge occurred from 1648–1666"},
#   {"question": "Who were the main combatants in the Deluge?", "answer": "A variable amount, as multiple sides are involved"},
#   {"question": "Where did the Deluge take place?", "answer": "The Deluge took place in Poland–Lithuania"},
# RAG chunks saved to 'rag_chunks.pkl' and 'rag_chunks.csv'

# %%
df_rag_chunks
# Out:
#                                                  text  \
# 0   Q: What were the estimated death ranges for Wo...
# 1   Q: When did World War II take place? A: World ...
# 2   Q: Which sides fought in World War II? A: Alli...
# 3   Q: What was the estimated death range for Mong...
# 4   Q: When did the Mongol invasions and conquests...
# 5   Q: Which sides fought in the Mongol invasions ...
# 6   Q: What was the estimated death range for Thre...
# 7   Q: When did the Three Kingdoms take place? A: ...
# 8   Q: Which sides fought in the Three Kingdoms? A...
# 9   Q: What was the estimated death range for Taip...
# 10  Q: When did the Taiping Rebellion take place? ...
# 11  Q: Which sides fought in the Taiping Rebellion...
# 12  Q: What was the estimated death range for Worl...
# 13  Q: When did World War I take place? A: World W...
# 14  Q: Which sides fought in World War I? A: Allie...
# 15  Q: What was the estimated death range for Manc...
# 16  Q: When did the Manchu Conquest of China take ...
# 17  Q: Which sides fought in the Manchu Conquest o...
# 18  Q: What was the estimated death range for Conq...
# 19  Q: When did the Conquests of Timur take place?...
# 20  Q: Which sides fought in the Conquests of Timu...
# 21  Q: What was the estimated death range for An L...
# 22  Q: When did the An Lushan rebellion take place...
# 23  Q: Which sides fought in the An Lushan rebelli...
# 24  Q: What was the estimated death range for Thir...
# 25  Q: When did the Thirty Years' War take place? ...
# 26  Q: Which sides fought in the Thirty Years' War...
# 27  Q: What was the estimated death range for Span...
# 28  Q: When did the Spanish conquest of Mexico tak...
# 29  Q: Which sides fought in the Spanish conquest ...
# 30  Q: What was the estimated death range for Span...
# 31  Q: When did the Spanish conquest of the Inca E...
# 32  Q: Which sides fought in the Spanish conquest ...
# 33  Q: What was the estimated death range for Russ...
# 34  Q: When did the Russian Civil War take place? ...
# 35  Q: Which sides fought in the Russian Civil War...
# 36  Q: What was the estimated death range for Chin...
# 37  Q: When did the Chinese Civil War take place? ...
#
#                                                   url
# 0   https://en.wikipedia.org/wiki/List_of_wars_by_...
# 1   https://en.wikipedia.org/wiki/List_of_wars_by_...
# 2   https://en.wikipedia.org/wiki/List_of_wars_by_...
# 3   https://en.wikipedia.org/wiki/List_of_wars_by_...
# 4   https://en.wikipedia.org/wiki/List_of_wars_by_...
# 5   https://en.wikipedia.org/wiki/List_of_wars_by_...
# 6   https://en.wikipedia.org/wiki/List_of_wars_by_...
# 7   https://en.wikipedia.org/wiki/List_of_wars_by_...
# 8   https://en.wikipedia.org/wiki/List_of_wars_by_...
# 9   https://en.wikipedia.org/wiki/List_of_wars_by_...
# 10  https://en.wikipedia.org/wiki/List_of_wars_by_...
# 11  https://en.wikipedia.org/wiki/List_of_wars_by_...
# 12  https://en.wikipedia.org/wiki/List_of_wars_by_...
# 13  https://en.wikipedia.org/wiki/List_of_wars_by_...
# 14  https://en.wikipedia.org/wiki/List_of_wars_by_...
# 15  https://en.wikipedia.org/wiki/List_of_wars_by_...
# 16  https://en.wikipedia.org/wiki/List_of_wars_by_...
# 17  https://en.wikipedia.org/wiki/List_of_wars_by_...
# 18  https://en.wikipedia.org/wiki/List_of_wars_by_...
# 19  https://en.wikipedia.org/wiki/List_of_wars_by_...
# 20  https://en.wikipedia.org/wiki/List_of_wars_by_...
# 21  https://en.wikipedia.org/wiki/List_of_wars_by_...
# 22  https://en.wikipedia.org/wiki/List_of_wars_by_...
# 23  https://en.wikipedia.org/wiki/List_of_wars_by_...
# 24  https://en.wikipedia.org/wiki/List_of_wars_by_...
# 25  https://en.wikipedia.org/wiki/List_of_wars_by_...
# 26  https://en.wikipedia.org/wiki/List_of_wars_by_...
# 27  https://en.wikipedia.org/wiki/List_of_wars_by_...
# 28  https://en.wikipedia.org/wiki/List_of_wars_by_...
# 29  https://en.wikipedia.org/wiki/List_of_wars_by_...
# 30  https://en.wikipedia.org/wiki/List_of_wars_by_...
# 31  https://en.wikipedia.org/wiki/List_of_wars_by_...
# 32  https://en.wikipedia.org/wiki/List_of_wars_by_...
# 33  https://en.wikipedia.org/wiki/List_of_wars_by_...
# 34  https://en.wikipedia.org/wiki/List_of_wars_by_...
# 35  https://en.wikipedia.org/wiki/List_of_wars_by_...
# 36  https://en.wikipedia.org/wiki/List_of_wars_by_...
# 37  https://en.wikipedia.org/wiki/List_of_wars_by_...
